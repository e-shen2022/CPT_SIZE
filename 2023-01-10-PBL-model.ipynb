# %% [markdown]
# # Model and Object-Oriented Programming
# > Object Oriented Programming is a part of learning Python.  The objective of this blog is to introduce OOP with the intention of PBL task to create a database.  The foundations for a database is defining a Class and understanding instance data and methods.  A database is often a focus of backend coding as it will store persistent data, that can be recalled after the immediate session is closed.
#
# - title: Model and Object-Oriented Programming
# - toc: true
# - categories: []
# - image: /images/python.png
# - type: pbl
# - week: 18

# %% [markdown]
# ## Class and Object Terms
# > The foundations of Object-Oriented Programming is defining a ***Class***
# * In Object-Oriented Programming (OOP), a class is a blueprint for creating an ***Object***. (a data structure).  An Object is used like many other Python variables.
# * A Class has ...
#     * a collection of data, these are called ***Attributes*** and in Python are pre-fixed using the keyword ***self***
#     * a collection of Functions/Procedures.  These are called ***Methods** when they exist inside a Class definition.
# * An Object is created from the Class/Template.  Characteristics of objects ...
#    * an Object is an ***Instance*** of the Class/Template
#    * there can be many Objects created from the same Class
#    * each Object contains its own ***Instance Data***
#    * the data is setup by the ***Constructor***, this is the "__init__" method in a Python class
#    * all methods in the Class/Template become part of the Object, methods are accessed using ***dot notation*** (object.method())
# * A Python Class allow for the definition of @ decorators, these allow access to instance data without the use of functions ...
#     * @property decorator (aka getter).  This enables developers to reference/get instance data in a shorthand fashion (object.name versus object.get_name())
#     * @name.setter decorator (aka setter).  This enables developers to update/set instance data in a shorthand fashion (object.name = "John" versus object.set_name("John"))
#     * observe all instance data (self._name, self._email ...) are prefixed with "_", this convention allows setters and getters to work with more natural variable name (name, email ...)

# %% [markdown]
# ## Class and Object Code

# %%
# Werkzeug is a collection of libraries that can be used to create a WSGI (Web Server Gateway Interface)
# A gateway in necessary as a web server cannot communicate directly with Python.
# In this case, imports are focused on generating hash code to protect passwords.
from werkzeug.security import generate_password_hash, check_password_hash
import json

# Define a User Class/Template
# -- A User represents the data we want to manage
class User:    
    # constructor of a User object, initializes the instance variables within object (self)
    def __init__(self, name, uid, password):
        self._name = name    # variables with self prefix become part of the object, 
        self._uid = uid
        self.set_password(password)

    # a name getter method, extracts name from object
    @property
    def name(self):
        return self._name
    
    # a setter function, allows name to be updated after initial object creation
    @name.setter
    def name(self, name):
        self._name = name
    
    # a getter method, extracts email from object
    @property
    def uid(self):
        return self._uid
    
    # a setter function, allows name to be updated after initial object creation
    @uid.setter
    def uid(self, uid):
        self._uid = uid
        
    # check if uid parameter matches user id in object, return boolean
    def is_uid(self, uid):
        return self._uid == uid
    
    @property
    def password(self):
        return self._password[0:10] + "..." # because of security only show 1st characters

    # update password, this is conventional setter
    def set_password(self, password):
        """Create a hashed password."""
        self._password = generate_password_hash(password, method='sha256')

    # check password parameter versus stored/encrypted password
    def is_password(self, password):
        """Check against hashed password."""
        result = check_password_hash(self._password, password)
        return result
    
    # output content using str(object) in human readable form, uses getter
    def __str__(self):
        return f'name: "{self.name}", id: "{self.uid}", psw: "{self.password}"'

    # output command to recreate the object, uses attribute directly
    def __repr__(self):
        return f'Person(name={self._name}, uid={self._uid}, password={self._password})'


# tester method to print users
def tester(users, uid, psw):
    result = None
    for user in users:
        # test for match in database
        if user.uid == uid and user.is_password(psw):  # check for match
            print("* ", end="")
            result = user
        # print using __str__ method
        print(str(user))
    return result
        

# place tester code inside of special if!  This allows include without tester running
#Note: this is important - if using multiple files
if __name__ == "__main__":

    # define user objects
    u1 = User(name='Thomas Edison', uid='toby', password='123toby')
    u2 = User(name='Nicholas Tesla', uid='nick', password='123nick')
    u3 = User(name='Alexander Graham Bell', uid='lex', password='123lex')
    u4 = User(name='Eli Whitney', uid='eli', password='123eli')
    u5 = User(name='Hedy Lemarr', uid='hedy', password='123hedy')

    # put user objects in list for convenience
    users = [u1, u2, u3, u4, u5]

    # Find user
    print("Test 1, find user 3")
    u = tester(users, u3.uid, "123lex")
    print("Hello")


    # Change user
    print("Test 2, change user 3")
    u.name = "John Mortensen"
    u.uid = "jm1021"
    u.set_password("123qwerty")
    u = tester(users, u.uid, "123qwerty")


    # Make dictionary
    ''' 
    The __dict__ in Python represents a dictionary or any mapping object that is used to store the attributes of the object. 
    Every object in Python has an attribute that is denoted by __dict__. 
    Use the json.dumps() method to convert the list of Users to a JSON string.
    '''
    print("Test 3, make a dictionary")
    json_string = json.dumps([user.__dict__ for user in users]) 
    print(json_string)

    print("Test 4, make a dictionary")
    json_string = json.dumps([vars(user) for user in users]) 
    print(json_string)
# Out:
# Test 1, find user 3
# name: "Thomas Edison", id: "toby", psw: "sha256$ozy..."
# name: "Nicholas Tesla", id: "nick", psw: "sha256$rG2..."
# * name: "Alexander Graham Bell", id: "lex", psw: "sha256$oMu..."
# name: "Eli Whitney", id: "eli", psw: "sha256$Hws..."
# name: "Hedy Lemarr", id: "hedy", psw: "sha256$mI9..."
# Hello
# Test 2, change user 3
# name: "Thomas Edison", id: "toby", psw: "sha256$ozy..."
# name: "Nicholas Tesla", id: "nick", psw: "sha256$rG2..."
# * name: "John Mortensen", id: "jm1021", psw: "sha256$a8F..."
# name: "Eli Whitney", id: "eli", psw: "sha256$Hws..."
# name: "Hedy Lemarr", id: "hedy", psw: "sha256$mI9..."
# Test 3, make a dictionary
# [{"_name": "Thomas Edison", "_uid": "toby", "_password": "sha256$ozyOQ4adCNmIMQQ4$4f33b47dde7aed37379362ba58737e5dced42ae546328c85c1dce634a9772dc3"}, {"_name": "Nicholas Tesla", "_uid": "nick", "_password": "sha256$rG2gSgviHNmb3EgC$fc3d59ef3ee7780e3d9d6d40539426437d7d3a6e1bddd88f7e9b650bbc265b7f"}, {"_name": "John Mortensen", "_uid": "jm1021", "_password": "sha256$a8FnuLa5KAXXjl6x$7ba9faf32c8ddbf0e3d36dab343fd5b593609e7875956f9ed33d03a669d5ca0d"}, {"_name": "Eli Whitney", "_uid": "eli", "_password": "sha256$HwsZexPi1i2aRiu9$a91dd69cdda9b24c17e49c972d311d557b66e16d5cc62fccff07280c093e36d6"}, {"_name": "Hedy Lemarr", "_uid": "hedy", "_password": "sha256$mI9uSTtwOqUnEV37$b6cb61f9430d461fa5f00359aa65f747f8a817e1f74fea95d56a4bebb6a59db5"}]
# Test 4, make a dictionary
# [{"_name": "Thomas Edison", "_uid": "toby", "_password": "sha256$ozyOQ4adCNmIMQQ4$4f33b47dde7aed37379362ba58737e5dced42ae546328c85c1dce634a9772dc3"}, {"_name": "Nicholas Tesla", "_uid": "nick", "_password": "sha256$rG2gSgviHNmb3EgC$fc3d59ef3ee7780e3d9d6d40539426437d7d3a6e1bddd88f7e9b650bbc265b7f"}, {"_name": "John Mortensen", "_uid": "jm1021", "_password": "sha256$a8FnuLa5KAXXjl6x$7ba9faf32c8ddbf0e3d36dab343fd5b593609e7875956f9ed33d03a669d5ca0d"}, {"_name": "Eli Whitney", "_uid": "eli", "_password": "sha256$HwsZexPi1i2aRiu9$a91dd69cdda9b24c17e49c972d311d557b66e16d5cc62fccff07280c093e36d6"}, {"_name": "Hedy Lemarr", "_uid": "hedy", "_password": "sha256$mI9uSTtwOqUnEV37$b6cb61f9430d461fa5f00359aa65f747f8a817e1f74fea95d56a4bebb6a59db5"}]

# %% [markdown]
# ## Hacks
# > Add new attributes/variables to the Class.  Make class specific to your CPT work.
# - Add classOf attribute to define year of graduation
#     - Add setter and getter for classOf
# - Add dob attribute to define date of birth
#     - This will require investigation into Python datetime objects as shown in example code below
#     - Add setter and getter for dob
# - Add instance variable for age, make sure if dob changes age changes
#     - Add getter for age, but don't add/allow setter for age
# - Update and format tester function to work with changes
#
# > Start a class design for each of your own Full Stack CPT sections of your project
# - Use new `code cell` in this notebook
# - Define _init_ and self attributes
# - Define setters and getters
# - Make a tester
#
# attribute: bday
# class w/attributes that fits with project

# %% [markdown]
# ## Start Code for Hacks

# %%
#project: skin product recommendation
#questions: male or female, age, dry/oil/combination skin, allergies, fragrance/nofragrance check boxes 
#submit button --> append data into data base (dictionary)

from werkzeug.security import generate_password_hash, check_password_hash
import json
from datetime import date, datetime

# Define a User Class/Template
class User:    
    # constructor of a User object, initializes the instance variables within object (self)
    def __init__(self, name, uid, password, dob, gradYear, gender, skinType, allergies, fragrance):
        self._name = name    # variables with self prefix become part of the object, 
        self._uid = uid
        self.set_password(password)
        #Added dob, gradYear, gender, skinType, allergies, and fragrance for CPT 
        self._dob = dob
        self._gradYear = gradYear
        self._gender = gender
        self._skinType = skinType
        self._allergies = allergies
        self._fragrance = fragrance
        
    # a name getter method, extracts name from object
    @property
    def name(self):
        return self._name
    
    # a setter function, allows name to be updated after initial object creation
    @name.setter
    def name(self, name):
        self._name = name
    
    @property
    def uid(self):
        return self._uid
    
    @uid.setter
    def uid(self, uid):
        self._uid = uid
        
    def is_uid(self, uid):
        return self._uid == uid
    
    @property
    def dob(self):
        return self._dob
    
    @dob.setter
    def dob(self, dob):
        self._dob = dob

    @property
    def gradYear(self):
        return self._gradYear
    
    @gradYear.setter
    def gradYear(self, gradYear):
        self._gradeYear = gradYear

    @property
    def gender(self):
        return self._gender
    
    @gender.setter
    def gender(self, gender):
        self._gender = gender
    
    @property
    def skinType(self):
        return self.skinType
    
    @skinType.setter
    def skinType(self, skinType):
        self._skinType = skinType

    @property
    def allergies(self):
        return self.allergies
    
    @allergies.setter
    def allergies(self, allergies):
        self._allergies = allergies

    @property
    def fragrance(self):
        return self.fragrance
    
    @fragrance.setter
    def fragrance(self, fragrance):
        self._fragrance = fragrance
   
    @property
    def password(self):
        return self._password[0:10] + "..."

    # update password, this is conventional setter
    def set_password(self, password):
        """Create a hashed password."""
        self._password = generate_password_hash(password, method='sha256')

    # check password parameter versus stored/encrypted password
    def is_password(self, password):
        """Check against hashed password."""
        result = check_password_hash(self._password, password)
        return result
    
    # output content using str(object) in human readable form, uses getter
    def __str__(self):
        return f"name: '{self.name}', id: '{self.uid}', psw: '{self.password}', dob: '{self.dob.strftime('%m/%d/%Y')}', gradYear: '{self.gradYear}', gender: '{self.gender}'"
    #Note: not able to print all attributes bc of size limit --> find out how to fix 
    #,skinType: '{self.skinType}', allergies: "{self.allergies}", fragrance: "{self.fragrance}",    

# tester method to print users
def tester(users, uid, psw):
    #print("ur mom")
    result = None
    for user in users:
        print(user.uid == uid)
        # test for match in database
        if user.uid == uid and user.is_password(psw):  # check for match
            print("* ", end="")
            result = user
            break
        # print using __str__ method
        print(str(user))
    return result
        

#import sys
#sys.setrecursionlimit(9000)

# place tester code inside of special if!  This allows include without tester running
#Note: this is important - if using multiple files
if __name__ == "__main__":

# added new birthdays and users
    birthday1 = date(2006, 7, 29)
    birthday2 = date(2001, 11, 14)
    birthday3 = date(2006, 8, 23)
    birthday4 = date(1965, 4, 1)
    birthday5 = date(2023, 1, 1)
    u1 = User(name='Emma Shen', uid='emma', password='123emma', dob = birthday1, gradYear = '2024', gender = 'female', skinType = 'oily', allergies = 'dustmites', fragrance = 'yes')
    u2 = User(name='Alan Shen', uid='alan', password='123alan', dob = birthday2, gradYear = '2020', gender = 'male', skinType = 'oily', allergies = 'nothing', fragrance = 'no')
    u3 = User(name='Julia Huynh', uid='julia', password='123julia', dob = birthday3, gradYear = '2024', gender = 'female', skinType = 'dry', allergies = 'nothing', fragrance = 'yes')
    u4 = User(name='Xin Tian', uid='emma', password='123xin', dob = birthday4, gradYear = '1983', gender = 'female', skinType = 'combination', allergies = 'nothing', fragrance = 'yes')
    u5 = User(name='Sean Yeung', uid='sean', password='123sean', dob = birthday5, gradYear = 'undetermined', gender = 'male', skinType = 'dry', allergies = 'nothing', fragrance = 'yes')

    # put user objects in list for convenience
    users = [u1, u2, u3, u4, u5]

    # Find Julia!
    print("Test 1, find user 3")
    u = tester(users, u3.uid, "123julia")
    print(type(u))

    # Change user
    print("Test 2, change user 3")
    u.name = "John Mortensen"
    u.uid = "jm1021"
    u.set_password("123qwerty")
    u = tester(users, u.uid, "123qwerty")

    print("Test 3, make a dictionary")
    #Note: serialize datetime to json string 
    json_string = json.dumps([user.__dict__ for user in users], default=str) 
    print(json_string)
  

    print("Test 4, make a dictionary")
    json_string = json.dumps([vars(user) for user in users],default=str) 
    print(json_string)
# Out:
# Test 1, find user 3
# False
# name: 'Emma Shen', id: 'emma', psw: 'sha256$uqv...', dob: '07/29/2006', gradYear: '2024', gender: 'female'
# False
# name: 'Alan Shen', id: 'alan', psw: 'sha256$6cd...', dob: '11/14/2001', gradYear: '2020', gender: 'male'
# True
# * <class '__main__.User'>
# Test 2, change user 3
# False
# name: 'Emma Shen', id: 'emma', psw: 'sha256$uqv...', dob: '07/29/2006', gradYear: '2024', gender: 'female'
# False
# name: 'Alan Shen', id: 'alan', psw: 'sha256$6cd...', dob: '11/14/2001', gradYear: '2020', gender: 'male'
# True
# * Test 3, make a dictionary
# [{"_name": "Emma Shen", "_uid": "emma", "_password": "sha256$uqvLPmsDk6yzRn5z$1aa865710452f0fb1270c231eeaeefb5d8ee3e2877f68cfd8e81035df4399c98", "_dob": "2006-07-29", "_gradYear": "2024", "_gender": "female", "_skintype": "oily", "_allergies": "dustmites", "_fragrance": "yes"}, {"_name": "Alan Shen", "_uid": "alan", "_password": "sha256$6cdFHUqV6XTphgLh$fc238c48a37b947eb4051586157949bfae426bcf608580a220f4794df37a8dc5", "_dob": "2001-11-14", "_gradYear": "2020", "_gender": "male", "_skintype": "oily", "_allergies": "nothing", "_fragrance": "no"}, {"_name": "John Mortensen", "_uid": "jm1021", "_password": "sha256